# %% [markdown]
# # Modelo

# %% [markdown]
# - [Cargue de datos](#Cargue-Datos)
# - [Reglas establecidas](#Reglas)
# - Modelo
#     - [Regresión Logistica](#Regresion-Logistica)
#     - [DecisionTree](#DecisionTree)
#     - [RandomForest](#RandomForest)
# - [Justicia](#Justicia)
#     - [Genero](#Genero)
#     - [Ciudad Residencia](#Ciudad-Residencia)
#     - [Estrato](#Estrato)
# - [Selección Modelo](#Seleccion-Modelo)
#     - [Comparación de Modelos](#Comparacion-de-modelos)
#     - [Generar joblib](#Generar-joblib)
# - [Equivalencias de datos](#Equivalencia-Datos)

# %% [markdown]
# ## Librería

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter, FormatStrFormatter

import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from sklearn.preprocessing import LabelEncoder # Import LabelEncoder

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import ConfusionMatrixDisplay,accuracy_score, confusion_matrix, classification_report,mean_absolute_error, mean_squared_error, r2_score,roc_curve, auc, roc_auc_score, roc_curve,precision_score,recall_score,f1_score
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.tree import DecisionTreeClassifier,plot_tree

import joblib
import warnings
import sys
import os
import random

# Imprimir el texto en celda
from IPython.display import Markdown, display, HTML

# %%
# configuración
warnings.filterwarnings('ignore')

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option('display.max_colwidth', 128)
pd.set_option('display.float_format', '{:.2f}'.format)  # 2 decimales
pd.set_option('expand_frame_repr', False)
np.set_printoptions(threshold=sys.maxsize)

# %%
# Establecer la semilla general
seed_value = 42
random.seed(seed_value)
np.random.seed(seed_value)

# %%
# Función para formatear a dos decimales
def decimal_formatter(x, _):
    return f"{x:,.2f}" 

def decimal_formatter2(x):
    return f"{x:,.2f}"

# %%
def calculate_target(row):
    """
    Función para definir el valor de target de acuerdo a las reglas
    
    :param 
        row: Columna de la cual se revisa el target
    :return 
        target: Valor 0, si corresponde a deserción; Valor 1 si mantiene sus estudios
    """
    target=0
    if (row['SITUACION_ACTUAL'] == 'EXCLUIDO NO RENOVACION DE MATRICULA' or row["SITUACION_ACTUAL"]=='RETIRO DEFINITIVO' or row["SITUACION_ACTUAL"]=='EXCLUIDO CANCELACION SEMESTRE' ) and  (row['CATEGORIA_ACTUAL'] != "CONTINUIDAD ACADEMICA - EGRESADO") :
        target=0
    else:
        target=1
    
    return target

# %% [markdown]
# ## Cargue Datos
# ([Volver al Inicio](#Modelo))

# %%
# Carga de datos
data = pd.read_csv('../stage/clean.csv', sep=",", encoding='utf-8', quotechar='"')

# %%
data.rename(columns={'CODIGOPROGRAMA':'PROGRAMA',
                     'COD_CIUDADRESIDENCIA': 'CIUDADRESIDENCIA', 
                     'COD_CIUDADNACIMIENTO':'CIUDADNACIMIENTO'}, inplace=True)

# %%
# Visualización de datos
data.head()
# Out:
#    ESTRATO  SEMESTRE  PROMEDIOSEMESTRE  EDAD2  PROGRAMA  GENERO  CIUDADRESIDENCIA  CIUDADNACIMIENTO  target
# 0     3.00         8              3.90     22    102383       1          76001.00          76001.00       1
# 1     3.00         8              4.50     27    102383       0          76001.00          76001.00       1
# 2     3.00         8              4.00     22    102383       0          76001.00          73001.00       1
# 3     3.00         8              4.80     26    102383       0          76001.00          76001.00       1
# 4     3.00         7              4.20     28    102383       0          76001.00          76001.00       1

# %%
# Visualización de datos
data.head()
# Out:
#    ESTRATO  SEMESTRE  PROMEDIOSEMESTRE  EDAD2  PROGRAMA  GENERO  CIUDADRESIDENCIA  CIUDADNACIMIENTO  target
# 0     3.00         8              3.90     22    102383       1          76001.00          76001.00       1
# 1     3.00         8              4.50     27    102383       0          76001.00          76001.00       1
# 2     3.00         8              4.00     22    102383       0          76001.00          73001.00       1
# 3     3.00         8              4.80     26    102383       0          76001.00          76001.00       1
# 4     3.00         7              4.20     28    102383       0          76001.00          76001.00       1

# %%
# dimension datasets
print(f'Dimensiones del dataset data : {data.shape[0]} registros, {data.shape[1]} columnas')
# Out:
# Dimensiones del dataset data : 9453 registros, 9 columnas

# %%
# Revisón de campos vacíos/nulos
nulos_y_tipos = pd.DataFrame({
    'nulos': data.isnull().sum(),
    'tipo_dato': data.dtypes
})
nulos_y_tipos
# Out:
#                   nulos tipo_dato
# ESTRATO               6   float64
# SEMESTRE              0     int64
# PROMEDIOSEMESTRE      0   float64
# EDAD2                 0     int64
# PROGRAMA              0     int64
# GENERO                0     int64
# CIUDADRESIDENCIA    364   float64
# CIUDADNACIMIENTO     67   float64
# target                0     int64

# %%
# Estadisticas del dataset
data.describe(include='all')
# Out:
#        ESTRATO  SEMESTRE  PROMEDIOSEMESTRE   EDAD2  PROGRAMA  GENERO  CIUDADRESIDENCIA  CIUDADNACIMIENTO  target
# count  9447.00   9453.00           9453.00 9453.00   9453.00 9453.00           9089.00           9386.00 9453.00
# mean      2.28      5.35              3.72   23.87  53294.78    0.59          69406.51          66281.08    0.86
# std       0.98      2.99              1.01    5.59  38069.42    0.49          18379.77          20905.78    0.34
# min       1.00      1.00              0.00   15.00   7305.00    0.00           5001.00           5001.00    0.00
# 25%       2.00      2.00              3.40   21.00   7306.00    0.00          76001.00          76001.00    1.00
# 50%       2.00      6.00              4.00   23.00  53212.00    1.00          76001.00          76001.00    1.00
# 75%       3.00      8.00              4.40   25.00  90555.00    1.00          76001.00          76001.00    1.00
# max       6.00     10.00              5.00   66.00 110783.00    1.00          95001.00          99773.00    1.00

# %%
data = data.dropna()
# Revisón de campos vacíos/nulos
nulos_y_tipos = pd.DataFrame({
    'nulos': data.isnull().sum(),
    'tipo_dato': data.dtypes
})
nulos_y_tipos
# Out:
#                   nulos tipo_dato
# ESTRATO               0   float64
# SEMESTRE              0     int64
# PROMEDIOSEMESTRE      0   float64
# EDAD2                 0     int64
# PROGRAMA              0     int64
# GENERO                0     int64
# CIUDADRESIDENCIA      0   float64
# CIUDADNACIMIENTO      0   float64
# target                0     int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Reglas
# ([Volver al Inicio](#Modelo))

# %% [markdown]
# Como parte de reglas establecidas, se menciona que se deben excluir el nivel de formación `Especialización`

# %% [markdown]
# Así mismo, de acuerdo con ENDEPORTE la forma de clasificar la deserción corresponde a lo siguiente:
#
# ![Reglas de Deserción](../../docs/regla.png)

# %% [markdown]
# Con base a lo anterior, se procede a calcular la columna `target` correspondiente a la deserción con la cual:
# - Valor `0` corresponde a estudiantes que desertan
# - Valor `1` corresponde a estudiantes que permanecen en sus estudios

# %%
data.head()
# Out:
#    ESTRATO  SEMESTRE  PROMEDIOSEMESTRE  EDAD2  PROGRAMA  GENERO  CIUDADRESIDENCIA  CIUDADNACIMIENTO  target
# 0     3.00         8              3.90     22    102383       1          76001.00          76001.00       1
# 1     3.00         8              4.50     27    102383       0          76001.00          76001.00       1
# 2     3.00         8              4.00     22    102383       0          76001.00          73001.00       1
# 3     3.00         8              4.80     26    102383       0          76001.00          76001.00       1
# 4     3.00         7              4.20     28    102383       0          76001.00          76001.00       1

# %%
df = data.copy()

# %% [markdown]
# ## Regresion Logistica
# ([Volver al Inicio](#Modelo))

# %%
# Separar las características (X) y la variable objetivo (y)
X = df.drop(columns=['target'])  # Excluir la columna target
y = df['target']  # Variable objetivo

# Dividir el conjunto en train + validation (80%) y test (20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed_value, stratify=y)

# Dividir el conjunto de train en train (80% de train) y validation (20% de train)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=seed_value, stratify=y_train)

# %%
# Confirmar las proporciones
print(f"Tamaño del conjunto de entrenamiento: {X_train.shape[0]}")
print(f"Tamaño del conjunto de validación: {X_val.shape[0]}")
print(f"Tamaño del conjunto de prueba: {X_test.shape[0]}")
# Out:
# Tamaño del conjunto de entrenamiento: 5778
# Tamaño del conjunto de validación: 1445
# Tamaño del conjunto de prueba: 1806

# %%
# Crear escalador y SMOTE
scaler = StandardScaler()
smote = SMOTE(random_state=seed_value)

# --- Regresión Logística (con escalado y SMOTE) ---
# Escalado en train, validation y test
x_lr_train_scaled = scaler.fit_transform(X_train)
x_lr_val_scaled = scaler.transform(X_val)
x_lr_test_scaled = scaler.transform(X_test)

# Aplicar SMOTE al conjunto de entrenamiento escalado
x_lr_train, y_lr_train = smote.fit_resample(x_lr_train_scaled, y_train)

# Guardar conjuntos de validación y prueba escalados
x_lr_val, y_lr_val = x_lr_val_scaled, y_val
x_lr_test, y_lr_test = x_lr_test_scaled, y_test

# --- DecisionTree (sin escalado, pero con SMOTE) ---
x_clf_train, y_clf_train = smote.fit_resample(X_train, y_train)
x_clf_val, y_clf_val = X_val, y_val  # Sin escalado
x_clf_test, y_clf_test = X_test, y_test  # Sin escalado

# --- Random Forest (sin escalado, pero con SMOTE) ---
x_rf_train, y_rf_train = smote.fit_resample(X_train, y_train)
x_rf_val, y_rf_val = X_val, y_val  # Sin escalado
x_rf_test, y_rf_test = X_test, y_test  # Sin escalado


# Confirmar distribuciones después de SMOTE
print("\nDistribución después de SMOTE para Regresión Logística (Train):")
print(pd.Series(y_lr_train).value_counts(normalize=True) * 100)

print("\nDistribución después de SMOTE para DecisionTree (Train):")
print(pd.Series(y_clf_train).value_counts(normalize=True) * 100)

print("\nDistribución después de SMOTE para Random Forest (Train):")
print(pd.Series(y_rf_train).value_counts(normalize=True) * 100)

print("\nConjuntos de datos preparados para Regresión Logística, Decision Tree y Random Forest ")
# Out:
# Distribución después de SMOTE para Regresión Logística (Train):
# target
# 1   50.00
# 0   50.00
# Name: proportion, dtype: float64
#
# Distribución después de SMOTE para DecisionTree (Train):
# target
# 1   50.00
# 0   50.00
# Name: proportion, dtype: float64
#
# Distribución después de SMOTE para Random Forest (Train):
# target
# 1   50.00
# 0   50.00
# Name: proportion, dtype: float64
#
# Conjuntos de datos preparados para Regresión Logística, Decision Tree y Random Forest

# %%
# Verificar la distribución de la variable target en el conjunto original
print(data['target'].value_counts(normalize=True))
# Out:
# target
# 1   0.86
# 0   0.14
# Name: proportion, dtype: float64

# %%
regression = LogisticRegression()

# %%
regression.fit(x_lr_train, y_lr_train)
# Out:
# LogisticRegression()

# %%
y_lr_pred = regression.predict(x_lr_test)

# %%
# Precisión del modelo
accuracy_lr = accuracy_score(y_lr_test, y_lr_pred)
print(f"Precisión: {accuracy_lr:.2f}")
# Out:
# Precisión: 0.70

# %%
# Matriz de confusión
print("\nMatriz de confusión:")
# Calcular la matriz de confusión
conf_matrix = confusion_matrix(y_lr_test, y_lr_pred)

# Mostrar la matriz de confusión 
disp = ConfusionMatrixDisplay(conf_matrix)
disp.plot(cmap='Blues')  
plt.show()
# Out:
# Matriz de confusión:

# %%
# Reporte de clasificación
print("\nReporte de clasificación Regresión Logística:")
report = classification_report(y_lr_test, y_lr_pred, output_dict=True)
reportF = classification_report(y_lr_test, y_lr_pred)
print(reportF)

precision_0 = report['0']['precision']
recall_0 = report['0']['recall']
f1_0 = report['0']['f1-score']
support_0 = report['0']['support']

precision_1 = report['1']['precision']
recall_1 = report['1']['recall']
f1_1 = report['1']['f1-score']
support_1 = report['1']['support']

accuracy = report['accuracy']
macro_avg = report['macro avg']
weighted_avg = report['weighted avg']
# Out:
# Reporte de clasificación Regresión Logística:
#               precision    recall  f1-score   support
#
#            0       0.28      0.77      0.42       246
#            1       0.95      0.69      0.80      1560
#
#     accuracy                           0.70      1806
#    macro avg       0.62      0.73      0.61      1806
# weighted avg       0.86      0.70      0.75      1806

# %%
markdown_text = f"""
Con lo anterior, se evidencia:

**Precisión**
- Para la clase 0 (deserción), la precisión es {decimal_formatter2(precision_0)}. Esto significa que, de todas las veces que el modelo predijo que un estudiante desertaría (predicción de "0"), el {decimal_formatter2(precision_0 * 100)}% de esas predicciones fueron correctas.
- Para la clase 1 (no deserción), la precisión es {decimal_formatter2(precision_1)}. Esto significa que, de todas las veces que el modelo predijo que un estudiante no desertaría (predicción de "1"), el {decimal_formatter2(precision_1 * 100)}% de esas predicciones fueron correctas.

**Recall**
- Para la clase 0 (deserción), el recall es {decimal_formatter2(recall_0)}. Esto indica que el modelo identificó correctamente el {decimal_formatter2(recall_0*100)}% de los estudiantes que realmente desertaron.
- Para la clase 1 (no deserción), el recall es {decimal_formatter2(recall_1)}. Esto indica que el modelo identificó correctamente el {decimal_formatter2(recall_1*100)}% de los estudiantes que NO desertaron.

**F1-Score**
- Para la clase 0 (deserción), el F1-score es {decimal_formatter2(f1_0)}. 
- Para la clase 1 (no deserción), el F1-score es {decimal_formatter2(f1_1)}. 
"""

# %%
display(Markdown(markdown_text))
# Out:
# Con lo anterior, se evidencia:
#
# **Precisión**
# - Para la clase 0 (deserción), la precisión es 0.28. Esto significa que, de todas las veces que el modelo predijo que un estudiante desertaría (predicción de "0"), el 28.40% de esas predicciones fueron correctas.
# - Para la clase 1 (no deserción), la precisión es 0.95. Esto significa que, de todas las veces que el modelo predijo que un estudiante no desertaría (predicción de "1"), el 95.07% de esas predicciones fueron correctas.
#
# **Recall**
# - Para la clase 0 (deserción), el recall es 0.77. Esto indica que el modelo identificó correctamente el 77.24% de los estudiantes que realmente desertaron.
# - Para la clase 1 (no deserción), el recall es 0.69. Esto indica que el modelo identificó correctamente el 69.29% de los estudiantes que NO desertaron.
#
# **F1-Score**
# - Para la clase 0 (deserción), el F1-score es 0.42.
# - Para la clase 1 (no deserción), el F1-score es 0.80.

# %%
print('MAE')
print("Train:", mean_absolute_error(y_lr_train, regression.predict(x_lr_train)))
print("Test :", mean_absolute_error(y_lr_test, regression.predict(x_lr_test)))
# Out:
# MAE
# Train: 0.24979959919839678
# Test : 0.296234772978959

# %%
print('RMSE')
print("Train:", np.sqrt(mean_squared_error(y_lr_train, regression.predict(x_lr_train))))
print("Test :", np.sqrt(mean_squared_error(y_lr_test, regression.predict(x_lr_test))))
# Out:
# RMSE
# Train: 0.49979955902181106
# Test : 0.5442745382423828

# %%
y_prob = regression.predict_proba(x_lr_test)[:, 1]  # Tomamos la probabilidad de la clase "1" (no deserción)
# Calcular el AUC-ROC
auc = roc_auc_score(y_lr_test, y_prob)
print(f"AUC-ROC: {auc:.2f}")

# Calcular los valores de la curva ROC
fpr, tpr, thresholds = roc_curve(y_lr_test, y_prob)

# Graficar la curva ROC
plt.figure(figsize=(10, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC curve (AUC = {auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Línea de referencia
plt.title('Curva ROC')
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# AUC-ROC: 0.79

# %% [markdown]
# ## DecisionTree
# ([Volver al Inicio](#Modelo))

# %%
# Árbo de decisión
clf = DecisionTreeClassifier(criterion='gini', max_depth=20, min_samples_split=2, min_samples_leaf=3, random_state = seed_value)
clf.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=20, min_samples_leaf=3, random_state=42)

# %%
# Se hace un poda del arbol
pruned_model = DecisionTreeClassifier(criterion='gini', max_depth=20, min_samples_split=2, min_samples_leaf=3, random_state = seed_value, ccp_alpha=3e-4)
pruned_model.fit(x_clf_train, y_clf_train)

print(f"Número de nodos del modelo original: {clf.tree_.node_count}")
print(f"Número de nodos de la versión podada: {pruned_model.tree_.node_count}")

plt.figure(figsize=(30,30))
plot_tree(pruned_model, filled=True, feature_names=X_train.columns)
plt.show()
# Out:
# Número de nodos del modelo original: 1771
# Número de nodos de la versión podada: 355

# %%
y_clf_pred = clf.predict(x_clf_test)

# %%
cm = confusion_matrix(y_clf_test, y_clf_pred)
cm_display = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = [False, True])
cm_display.plot(cmap='Blues')
plt.show()

# %%
# Obtener la importancia de los atributos
importances = clf.feature_importances_

# Ordenar los atributos por importancia
indices = np.argsort(importances)
plt.figure(figsize=(10,15))
plt.barh(range(x_clf_test.shape[1]), width=importances[indices], height=0.9)
plt.yticks(range(x_clf_test.shape[1]), np.array(X_test.columns)[indices])
plt.title("Importancia de características")
plt.xlabel("Importancia")
plt.ylabel("Característica")
plt.show()

# %%
# Reporte de clasificación
print("\nReporte de clasificación Decision Tree:")
report = classification_report(y_clf_test, y_clf_pred, output_dict=True)
reportF = classification_report(y_clf_test, y_clf_pred)
print(reportF)

clf_precision_0 = report['0']['precision']
clf_recall_0 = report['0']['recall']
clf_f1_0 = report['0']['f1-score']
clf_support_0 = report['0']['support']

clf_precision_1 = report['1']['precision']
clf_recall_1 = report['1']['recall']
clf_f1_1 = report['1']['f1-score']
clf_support_1 = report['1']['support']

clf_accuracy = report['accuracy']
clf_macro_avg = report['macro avg']
clf_weighted_avg = report['weighted avg']
# Out:
# Reporte de clasificación Decision Tree:
#               precision    recall  f1-score   support
#
#            0       0.77      0.77      0.77       246
#            1       0.96      0.96      0.96      1560
#
#     accuracy                           0.94      1806
#    macro avg       0.87      0.87      0.87      1806
# weighted avg       0.94      0.94      0.94      1806

# %% [markdown]
# ## RandomForest
# ([Volver al Inicio](#Modelo))

# %%
# Verificar la distribución en los subconjuntos de entrenamiento, validación y prueba
print('Distribución en el conjunto de entrenamiento (SMOTE aplicado):')
print(y_rf_train.value_counts(normalize=True))

print('\nDistribución en el conjunto de validación:')
print(y_rf_val.value_counts(normalize=True))

print('\nDistribución en el conjunto de prueba:')
print(y_rf_test.value_counts(normalize=True))
# Out:
# Distribución en el conjunto de entrenamiento (SMOTE aplicado):
# target
# 1   0.50
# 0   0.50
# Name: proportion, dtype: float64
#
# Distribución en el conjunto de validación:
# target
# 1   0.86
# 0   0.14
# Name: proportion, dtype: float64
#
# Distribución en el conjunto de prueba:
# target
# 1   0.86
# 0   0.14
# Name: proportion, dtype: float64

# %%
# Crear el modelo (por ejemplo, RandomForest)
rf = RandomForestClassifier(random_state=seed_value)

# Entrenar el modelo
rf.fit(x_rf_train, y_rf_train)

# Hacer predicciones en el conjunto de test
y_rf_pred = rf.predict(x_rf_test)

# Calcular la precisión general del modelo
accuracy_rf = accuracy_score(y_rf_test, y_rf_pred)
print(f"Precisión general del modelo: {decimal_formatter2(accuracy_rf)}")
# Out:
# Precisión general del modelo: 0.84

# %%
# Matriz de confusión
print("\nMatriz de confusión:")
# Calcular la matriz de confusión
conf_matrix_rf = confusion_matrix(y_rf_test, y_rf_pred)

# Mostrar la matriz de confusión 
disp = ConfusionMatrixDisplay(conf_matrix_rf)
disp.plot(cmap='Blues')  
plt.show()
# Out:
# Matriz de confusión:

# %%
# Reporte de clasificación
print("\nReporte de clasificación para Random Forest:")
report = classification_report(y_rf_test, y_rf_pred, output_dict=True)
reportF = classification_report(y_rf_test, y_rf_pred)
print(reportF)

rf_precision_0 = report['0']['precision']
rf_recall_0 = report['0']['recall']
rf_f1_0 = report['0']['f1-score']
rf_support_0 = report['0']['support']

rf_precision_1 = report['1']['precision']
rf_recall_1 = report['1']['recall']
rf_f1_1 = report['1']['f1-score']
rf_support_1 = report['1']['support']

rf_accuracy = report['accuracy']
rf_macro_avg = report['macro avg']
rf_weighted_avg = report['weighted avg']
# Out:
# Reporte de clasificación para Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.43      0.50      0.46       246
#            1       0.92      0.90      0.91      1560
#
#     accuracy                           0.84      1806
#    macro avg       0.68      0.70      0.69      1806
# weighted avg       0.85      0.84      0.85      1806

# %%
print('MAE')
print("Train:", decimal_formatter2(mean_absolute_error(y_rf_train, rf.predict(x_rf_train))))
print("Test :", decimal_formatter2(mean_absolute_error(y_rf_test, rf.predict(x_rf_test))))
# Out:
# MAE
# Train: 0.00
# Test : 0.16

# %%
print('RMSE')
print("Train:", decimal_formatter2(np.sqrt(mean_squared_error(y_rf_train, regression.predict(x_rf_train)))))
print("Test :", decimal_formatter2(np.sqrt(mean_squared_error(y_rf_test , regression.predict(x_rf_test )))))
# Out:
# RMSE
# Train: 0.69
# Test : 0.88

# %% [markdown]
# ## Justicia
# ([Volver al Inicio](#Modelo))
#
# Las medidas de justicia permiten evaluar si un modelo predice un resultado para todos de manera igualitaria para todos los valores de un atributo sensible; dentro de los datos se identificarion 3 atributos para aplicar justicia (Fairness):
# - [Genero](#Genero)
# - [Ciudad Residencia](#Ciudad-Residencia)
# - [Estrato](#Estrato)

# %% [markdown]
# ### Genero
# ([Volver al Inicio](#Modelo))

# %% [markdown]
# Para el campo de GENERO los valores corresponde a:
# - `0` Femenio
# - `1` Masculino

# %%
model = RandomForestClassifier(random_state=seed_value)

# Entrenar el modelo
model.fit(X_train, y_train)

# Separamos el conjunto de test según el género
X_test_masculino = X_test[X_test['GENERO'] == 1]
y_test_masculino = y_test[X_test['GENERO'] == 1]

X_test_femenino = X_test[X_test['GENERO'] == 0]
y_test_femenino = y_test[X_test['GENERO'] == 0]

# Realizamos las predicciones para cada grupo
y_pred_masculino = model.predict(X_test_masculino)
y_pred_femenino = model.predict(X_test_femenino)

# Calculamos la precisión para cada grupo
accuracy_masculino = accuracy_score(y_test_masculino, y_pred_masculino)
accuracy_femenino = accuracy_score(y_test_femenino, y_pred_femenino)

print(f"Precisión para género masculino: {accuracy_masculino}")
print(f"Precisión para género femenino: {accuracy_femenino}")
# Out:
# Precisión para género masculino: 0.8480300187617261
# Precisión para género femenino: 0.9013513513513514

# %%
# 3. Comparar el rendimiento entre grupos (Métrica de justicia)
# Diferencia de precisión entre masculino y femenino
precision_diferencia = abs(accuracy_masculino - accuracy_femenino)
print(f"Diferencia de precisión entre masculino y femenino: {decimal_formatter2(precision_diferencia)}")
# Out:
# Diferencia de precisión entre masculino y femenino: 0.05

# %% [markdown]
# El valor obtenido, demuestra solo existe una  Diferencia de precisión entre masculino y femenino de 0.05.

# %% [markdown]
# ### Ciudad Residencia
# ([Volver al Inicio](#Modelo))

# %%
# Crear el modelo (puedes usar otro modelo si prefieres)
model = RandomForestClassifier(random_state=seed_value)

# Entrenar el modelo
model.fit(X_train, y_train)

# Hacer predicciones en el conjunto de test
y_pred = model.predict(X_test)

# Calcular la precisión general del modelo
accuracy = accuracy_score(y_test, y_pred)
print(f"Precisión general del modelo: {accuracy}")
# Out:
# Precisión general del modelo: 0.8698781838316723

# %%
# Verificar si la columna 'CIUDADRESIDENCIA' existe en el DataFrame
print(X_test.columns)


# Separar el conjunto de datos según las ciudades
unique_cities = X_test['CIUDADRESIDENCIA'].unique()  # Obtén las ciudades únicas

# Crear un diccionario para almacenar las precisiones por ciudad
city_accuracy = {}

# Evaluar el modelo para cada ciudad
for city in unique_cities:
    # Filtrar los datos de prueba para la ciudad actual
    X_city = X_test[X_test['CIUDADRESIDENCIA'] == city]
    y_city = y_test[X_test['CIUDADRESIDENCIA'] == city]
    
    # Hacer las predicciones para esta ciudad
    y_pred_city = model.predict(X_city)
    
    # Calcular la precisión para esta ciudad
    accuracy_city = accuracy_score(y_city, y_pred_city)
    
    # Almacenar la precisión por ciudad
    city_accuracy[city] = accuracy_city

# Imprimir las precisiones por ciudad
for city, accuracy in city_accuracy.items():
    print(f"Precisión para {city}: {accuracy}")
# Out:
# Index(['ESTRATO', 'SEMESTRE', 'PROMEDIOSEMESTRE', 'EDAD2', 'PROGRAMA',
#        'GENERO', 'CIUDADRESIDENCIA', 'CIUDADNACIMIENTO'],
#       dtype='object')
# Precisión para 76001.0: 0.8529155787641427
# Precisión para 76036.0: 1.0
# Precisión para 86001.0: 0.6666666666666666
# Precisión para 76892.0: 0.90625
# Precisión para 52001.0: 1.0
# Precisión para 25612.0: 1.0
# Precisión para 19573.0: 0.8235294117647058
# Precisión para 76130.0: 0.9142857142857143
# Precisión para 76563.0: 1.0
# Precisión para 76250.0: 1.0
# Precisión para 73770.0: 1.0
# Precisión para 76622.0: 0.9090909090909091
# Precisión para 52399.0: 1.0
# Precisión para 76364.0: 0.855072463768116
# Precisión para 76520.0: 0.8958333333333334
# Precisión para 76109.0: 0.9444444444444444
# Precisión para 19100.0: 0.875
# Precisión para 17001.0: 1.0
# Precisión para 76869.0: 1.0
# Precisión para 19455.0: 0.8181818181818182
# Precisión para 76318.0: 0.8571428571428571
# Precisión para 41306.0: 0.0
# Precisión para 19698.0: 0.8947368421052632
# Precisión para 8141.0: 0.7916666666666666
# Precisión para 76834.0: 1.0
# Precisión para 76248.0: 0.9285714285714286
# Precisión para 70400.0: 1.0
# Precisión para 19513.0: 0.6666666666666666
# Precisión para 5059.0: 1.0
# Precisión para 50001.0: 1.0
# Precisión para 76377.0: 1.0
# Precisión para 76275.0: 0.8333333333333334
# Precisión para 76306.0: 0.8333333333333334
# Precisión para 76400.0: 1.0
# Precisión para 76233.0: 1.0
# Precisión para 15401.0: 1.0
# Precisión para 76670.0: 1.0
# Precisión para 63001.0: 1.0
# Precisión para 19022.0: 1.0
# Precisión para 18001.0: 1.0
# Precisión para 19001.0: 0.9230769230769231
# Precisión para 19780.0: 1.0
# Precisión para 5400.0: 1.0
# Precisión para 52473.0: 1.0
# Precisión para 52585.0: 1.0
# Precisión para 76823.0: 1.0
# Precisión para 15759.0: 1.0
# Precisión para 73001.0: 0.6666666666666666
# Precisión para 19137.0: 0.75
# Precisión para 19110.0: 1.0
# Precisión para 76895.0: 1.0
# Precisión para 19300.0: 0.8571428571428571
# Precisión para 86320.0: 1.0
# Precisión para 52490.0: 0.0
# Precisión para 15238.0: 1.0
# Precisión para 19142.0: 0.8571428571428571
# Precisión para 86219.0: 1.0
# Precisión para 66682.0: 1.0
# Precisión para 41298.0: 1.0
# Precisión para 19212.0: 1.0
# Precisión para 19290.0: 1.0
# Precisión para 76113.0: 1.0
# Precisión para 86568.0: 0.6
# Precisión para 68101.0: 1.0
# Precisión para 25473.0: 1.0
# Precisión para 66001.0: 0.0
# Precisión para 19318.0: 1.0
# Precisión para 76890.0: 1.0
# Precisión para 52356.0: 1.0
# Precisión para 52838.0: 1.0
# Precisión para 76100.0: 1.0
# Precisión para 81794.0: 1.0
# Precisión para 13670.0: 1.0
# Precisión para 19845.0: 1.0
# Precisión para 63212.0: 1.0
# Precisión para 18479.0: 1.0
# Precisión para 52250.0: 1.0
# Precisión para 19821.0: 1.0
# Precisión para 41001.0: 1.0
# Precisión para 91430.0: 1.0
# Precisión para 76736.0: 1.0
# Precisión para 52022.0: 1.0
# Precisión para 52207.0: 1.0
# Precisión para 52227.0: 1.0
# Precisión para 41807.0: 1.0
# Precisión para 19693.0: 1.0
# Precisión para 52565.0: 0.0
# Precisión para 63470.0: 1.0
# Precisión para 52786.0: 1.0
# Precisión para 70717.0: 1.0
# Precisión para 52036.0: 0.5
# Precisión para 23466.0: 1.0
# Precisión para 47001.0: 1.0
# Precisión para 76606.0: 1.0
# Precisión para 52079.0: 1.0
# Precisión para 54680.0: 1.0
# Precisión para 76147.0: 1.0
# Precisión para 52687.0: 1.0
# Precisión para 95001.0: 1.0
# Precisión para 18592.0: 1.0
# Precisión para 50590.0: 1.0
# Precisión para 68669.0: 1.0
# Precisión para 52411.0: 1.0
# Precisión para 86885.0: 1.0

# %%
# Calcular la diferencia de precisión entre la ciudad con mejor y peor rendimiento
max_accuracy = max(city_accuracy.values())  # Mejor precisión
min_accuracy = min(city_accuracy.values())  # Peor precisión

# Diferencia de precisión
accuracy_difference = max_accuracy - min_accuracy
print(f"Diferencia de precisión entre la mejor y la peor ciudad: {accuracy_difference}")
# Out:
# Diferencia de precisión entre la mejor y la peor ciudad: 1.0

# %%
from sklearn.metrics import recall_score

# Crear un diccionario para almacenar el recall por ciudad
city_recall = {}

# Evaluar el recall para cada ciudad
for city in unique_cities:
    # Filtrar los datos de prueba para la ciudad actual
    X_city = X_test[X_test['CIUDADRESIDENCIA'] == city]
    y_city = y_test[X_test['CIUDADRESIDENCIA'] == city]
    
    # Hacer las predicciones para esta ciudad
    y_pred_city = model.predict(X_city)
    
    # Calcular el recall para esta ciudad
    recall_city = recall_score(y_city, y_pred_city)
    
    # Almacenar el recall por ciudad
    city_recall[city] = recall_city

# Imprimir los recalls por ciudad
for city, recall in city_recall.items():
    print(f"Recall para {city}: {recall}")
# Out:
# Recall para 76001.0: 0.9489274770173647
# Recall para 76036.0: 1.0
# Recall para 86001.0: 1.0
# Recall para 76892.0: 0.9615384615384616
# Recall para 52001.0: 1.0
# Recall para 25612.0: 1.0
# Recall para 19573.0: 1.0
# Recall para 76130.0: 1.0
# Recall para 76563.0: 1.0
# Recall para 76250.0: 1.0
# Recall para 73770.0: 1.0
# Recall para 76622.0: 1.0
# Recall para 52399.0: 1.0
# Recall para 76364.0: 0.95
# Recall para 76520.0: 0.9767441860465116
# Recall para 76109.0: 1.0
# Recall para 19100.0: 1.0
# Recall para 17001.0: 1.0
# Recall para 76869.0: 1.0
# Recall para 19455.0: 1.0
# Recall para 76318.0: 1.0
# Recall para 41306.0: 0.0
# Recall para 19698.0: 1.0
# Recall para 8141.0: 0.95
# Recall para 76834.0: 1.0
# Recall para 76248.0: 1.0
# Recall para 70400.0: 1.0
# Recall para 19513.0: 0.6666666666666666
# Recall para 5059.0: 1.0
# Recall para 50001.0: 1.0
# Recall para 76377.0: 1.0
# Recall para 76275.0: 1.0
# Recall para 76306.0: 1.0
# Recall para 76400.0: 1.0
# Recall para 76233.0: 1.0
# Recall para 15401.0: 1.0
# Recall para 76670.0: 1.0
# Recall para 63001.0: 1.0
# Recall para 19022.0: 1.0
# Recall para 18001.0: 1.0
# Recall para 19001.0: 1.0
# Recall para 19780.0: 1.0
# Recall para 5400.0: 1.0
# Recall para 52473.0: 1.0
# Recall para 52585.0: 1.0
# Recall para 76823.0: 1.0
# Recall para 15759.0: 1.0
# Recall para 73001.0: 1.0
# Recall para 19137.0: 0.75
# Recall para 19110.0: 1.0
# Recall para 76895.0: 1.0
# Recall para 19300.0: 1.0
# Recall para 86320.0: 1.0
# Recall para 52490.0: 0.0
# Recall para 15238.0: 1.0
# Recall para 19142.0: 0.8333333333333334
# Recall para 86219.0: 1.0
# Recall para 66682.0: 1.0
# Recall para 41298.0: 1.0
# Recall para 19212.0: 1.0
# Recall para 19290.0: 1.0
# Recall para 76113.0: 1.0
# Recall para 86568.0: 0.75
# Recall para 68101.0: 1.0
# Recall para 25473.0: 1.0
# Recall para 66001.0: 0.0
# Recall para 19318.0: 1.0
# Recall para 76890.0: 1.0
# Recall para 52356.0: 1.0
# Recall para 52838.0: 1.0
# Recall para 76100.0: 1.0
# Recall para 81794.0: 1.0
# Recall para 13670.0: 1.0
# Recall para 19845.0: 1.0
# Recall para 63212.0: 1.0
# Recall para 18479.0: 1.0
# Recall para 52250.0: 1.0
# Recall para 19821.0: 1.0
# Recall para 41001.0: 1.0
# Recall para 91430.0: 1.0
# Recall para 76736.0: 1.0
# Recall para 52022.0: 1.0
# Recall para 52207.0: 1.0
# Recall para 52227.0: 1.0
# Recall para 41807.0: 1.0
# Recall para 19693.0: 1.0
# Recall para 52565.0: 0.0
# Recall para 63470.0: 1.0
# Recall para 52786.0: 1.0
# Recall para 70717.0: 1.0
# Recall para 52036.0: 1.0
# Recall para 23466.0: 1.0
# Recall para 47001.0: 1.0
# Recall para 76606.0: 1.0
# Recall para 52079.0: 1.0
# Recall para 54680.0: 1.0
# Recall para 76147.0: 1.0
# Recall para 52687.0: 1.0
# Recall para 95001.0: 1.0
# Recall para 18592.0: 1.0
# Recall para 50590.0: 1.0
# Recall para 68669.0: 1.0
# Recall para 52411.0: 1.0
# Recall para 86885.0: 1.0

# %% [markdown]
# Con lo anterior, se evidencia "paridad" entre los datos y no se evidencian sesgos pronunciados en la información

# %% [markdown]
# ### Estrato
# ([Volver al Inicio](#Modelo))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Crear el modelo (puedes usar otro modelo si prefieres)
model = RandomForestClassifier(random_state=seed_value)

# Entrenar el modelo
model.fit(X_train, y_train)

# Hacer predicciones en el conjunto de test
y_pred = model.predict(X_test)

# Calcular la precisión general del modelo
accuracy = accuracy_score(y_test, y_pred)
print(f"Precisión general del modelo: {accuracy}")
# Out:
# Precisión general del modelo: 0.8698781838316723

# %%
##2. Dividir los datos según ESTRATO

# Verificar si la columna 'ESTRATO' existe en el DataFrame
print(X_test.columns)

# Suponiendo que 'ESTRATO' es una columna categórica con diferentes niveles
# Separar el conjunto de datos según el estrato
unique_strata = X_test['ESTRATO'].unique()  # Obtén los estratos únicos

# Crear un diccionario para almacenar las precisiones por estrato
stratum_accuracy = {}

# Evaluar el modelo para cada estrato
for stratum in unique_strata:
    # Filtrar los datos de prueba para el estrato actual
    X_stratum = X_test[X_test['ESTRATO'] == stratum]
    y_stratum = y_test[X_test['ESTRATO'] == stratum]
    
    # Hacer las predicciones para este estrato
    y_pred_stratum = model.predict(X_stratum)
    
    # Calcular la precisión para este estrato
    accuracy_stratum = accuracy_score(y_stratum, y_pred_stratum)
    
    # Almacenar la precisión por estrato
    stratum_accuracy[stratum] = accuracy_stratum

# Imprimir las precisiones por estrato
for stratum, accuracy in stratum_accuracy.items():
    print(f"Precisión para el estrato {stratum}: {accuracy}")
# Out:
# Index(['ESTRATO', 'SEMESTRE', 'PROMEDIOSEMESTRE', 'EDAD2', 'PROGRAMA',
#        'GENERO', 'CIUDADRESIDENCIA', 'CIUDADNACIMIENTO'],
#       dtype='object')
# Precisión para el estrato 2.0: 0.862371888726208
# Precisión para el estrato 3.0: 0.8573913043478261
# Precisión para el estrato 1.0: 0.8894601542416453
# Precisión para el estrato 5.0: 0.8936170212765957
# Precisión para el estrato 4.0: 0.8932038834951457
# Precisión para el estrato 6.0: 1.0

# %%
## 3. Comparar el rendimiento entre los estratos (medida de justicia)
# Calcular la diferencia de precisión entre el estrato con mejor y peor rendimiento
max_accuracy = max(stratum_accuracy.values())  # Mejor precisión
min_accuracy = min(stratum_accuracy.values())  # Peor precisión

# Diferencia de precisión
accuracy_difference = max_accuracy - min_accuracy
print(f"Diferencia de precisión entre el mejor y el peor estrato: {accuracy_difference}")
# Out:
# Diferencia de precisión entre el mejor y el peor estrato: 0.14260869565217393

# %%
#4. Otras métricas de justicia
from sklearn.metrics import recall_score

# Crear un diccionario para almacenar el recall por estrato
stratum_recall = {}

# Evaluar el recall para cada estrato
for stratum in unique_strata:
    # Filtrar los datos de prueba para el estrato actual
    X_stratum = X_test[X_test['ESTRATO'] == stratum]
    y_stratum = y_test[X_test['ESTRATO'] == stratum]
    
    # Hacer las predicciones para este estrato
    y_pred_stratum = model.predict(X_stratum)
    
    # Calcular el recall para este estrato
    recall_stratum = recall_score(y_stratum, y_pred_stratum)
    
    # Almacenar el recall por estrato
    stratum_recall[stratum] = recall_stratum

# Imprimir los recalls por estrato
for stratum, recall in stratum_recall.items():
    print(f"Recall para el estrato {stratum}: {recall}")
# Out:
# Recall para el estrato 2.0: 0.9780405405405406
# Recall para el estrato 3.0: 0.9377593360995851
# Recall para el estrato 1.0: 0.9713467048710601
# Recall para el estrato 5.0: 0.9523809523809523
# Recall para el estrato 4.0: 0.9318181818181818
# Recall para el estrato 6.0: 1.0

# %% [markdown]
# ## Seleccion Modelo
# ([Volver al Inicio](#Modelo))

# %%
tabla_html = f"""<table style='width: 70%; text-align: center;'> 
    <tr>
        <th>Modelo</th>
        <th>target</th>
        <th>precision</th>
        <th>recall</th>
        <th>f1-score</th>
    </tr>
    <tr>
        <td rowspan="2">Logistic Regression</td>
        <td>0</td>
        <td>{decimal_formatter2(precision_0)}</td>
        <td>{decimal_formatter2(recall_0)}</td>
        <td>{decimal_formatter2(f1_0)}</td>
    </tr>
    <tr>
        <td>1</td>
        <td>{decimal_formatter2(precision_1)}</td>
        <td>{decimal_formatter2(recall_1)}</td>
        <td>{decimal_formatter2(f1_1)}</td>
    </tr>
    <tr>
        <td rowspan="2">Decision Tree</td>
        <td>0</td>
        <td>{decimal_formatter2(clf_precision_0)}</td>
        <td>{decimal_formatter2(clf_recall_0)}</td>
        <td>{decimal_formatter2(clf_f1_0)}</td>
    </tr>
    <tr>
        <td>1</td>
        <td>{decimal_formatter2(clf_precision_1)}</td>
        <td>{decimal_formatter2(clf_recall_1)}</td>
        <td>{decimal_formatter2(clf_f1_1)}</td>
    </tr>
    <tr>
        <td rowspan="2">Random Forest</td>
        <td>0</td>
        <td>{decimal_formatter2(rf_precision_0)}</td>
        <td>{decimal_formatter2(rf_recall_0)}</td>
        <td>{decimal_formatter2(rf_f1_0)}</td>
    </tr>
    <tr>
        <td>1</td>
        <td>{decimal_formatter2(rf_precision_1)}</td>
        <td>{decimal_formatter2(rf_recall_1)}</td>
        <td>{decimal_formatter2(rf_f1_1)}</td>
    </tr>
</table>
"""

# %% [markdown]
# Con base a los datos obtenidos entre los modelos de [Regresion Logistica](#Regresion-Logistica), [DecisionTree](#DecisionTree) y [RandomForest](#RandomForest), se evidencia los siguientes datos

# %%
# Mostrar la tabla HTML 
display(HTML(tabla_html))
# Out:
# <table style='width: 70%; text-align: center;'>
#     <tr>
#         <th>Modelo</th>
#         <th>target</th>
#         <th>precision</th>
#         <th>recall</th>
#         <th>f1-score</th>
#     </tr>
#     <tr>
#         <td rowspan="2">Logistic Regression</td>
#         <td>0</td>
#         <td>0.28</td>
#         <td>0.77</td>
#         <td>0.42</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>0.95</td>
#         <td>0.69</td>
#         <td>0.80</td>
#     </tr>
#     <tr>
#         <td rowspan="2">Decision Tree</td>
#         <td>0</td>
#         <td>0.77</td>
#         <td>0.77</td>
#         <td>0.77</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>0.96</td>
#         <td>0.96</td>
#         <td>0.96</td>
#     </tr>
#     <tr>
#         <td rowspan="2">Random Forest</td>
#         <td>0</td>
#         <td>0.43</td>
#         <td>0.50</td>
#         <td>0.46</td>
#     </tr>
#     <tr>
#         <td>1</td>
#         <td>0.92</td>
#         <td>0.90</td>
#         <td>0.91</td>
#     </tr>
# </table>

# %% [markdown]
# ### Comparacion de modelos
# ([Volver al Inicio](#Modelo))

# %%
# Crear un DataFrame para almacenar los valores reales y las predicciones
comparacion = {
    'Valor Real': y_test,
    'Predicción Regresión Logística': y_lr_pred,
    'Predicción Decision Tree': y_clf_pred,
    'Predicción Random Forest': y_rf_pred
}

df = pd.DataFrame(comparacion)

# %%
df.head(10)
# Out:
#       Valor Real  Predicción Regresión Logística  Predicción Decision Tree  Predicción Random Forest
# 6866           1                               1                         1                         1
# 968            1                               1                         1                         1
# 7920           1                               1                         1                         1
# 2979           0                               1                         0                         1
# 9069           0                               0                         0                         0
# 5758           1                               1                         1                         1
# 9384           1                               0                         1                         0
# 1471           1                               1                         1                         1
# 7565           1                               1                         1                         1
# 2258           1                               1                         1                         1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crear un DataFrame para almacenar los valores reales y las predicciones de cada modelo
df_melted = pd.melt(df, 
                    id_vars='Valor Real', 
                    value_vars=['Predicción Regresión Logística', 
                                'Predicción Decision Tree', 
                                'Predicción Random Forest'],
                    var_name='Modelo', 
                    value_name='Valor Predicho')

# Crear gráfico de barras
plt.figure(figsize=(14, 8))
ax = sns.barplot(x='Valor Real', y='Valor Predicho', hue='Modelo', data=df_melted, palette="muted")

# Agregar etiquetas de los valores reales y predichos sobre las barras
for p in ax.patches:
    # Obtener la posición de la barra
    height = p.get_height()
    width = p.get_width()
    x_position = p.get_x() + width / 2

    # Obtener los valores reales y predichos
    valor_real = p.get_x()  # x es la posición de la barra en el eje x
    valor_predicho = height  # el valor predicho está en el eje y

    # Mostrar los valores
    ax.text(x_position, height + 0.02, f"Real: {valor_real:.2f}\nPred: {valor_predicho:.2f}", 
            horizontalalignment='center', verticalalignment='bottom', fontsize=9)

# Agregar título y etiquetas
plt.title("Comparación de Valores Reales vs Predicciones por Modelo")
plt.xlabel("Valor Real")
plt.ylabel("Valor Predicho")
plt.legend()

# Mostrar el gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crear un DataFrame para almacenar los valores reales y las predicciones de cada modelo
df_melted = pd.melt(df, 
                    id_vars='Valor Real', 
                    value_vars=['Predicción Regresión Logística', 
                                'Predicción Decision Tree', 
                                'Predicción Random Forest'],
                    var_name='Modelo', 
                    value_name='Valor Predicho')

# Redondear las predicciones a 0 o 1
df_melted['Valor Predicho'] = df_melted['Valor Predicho'].round()

# Crear gráfico de barras
plt.figure(figsize=(14, 8))
ax = sns.barplot(x='Valor Real', y='Valor Predicho', hue='Modelo', data=df_melted, palette="muted")

# Agregar etiquetas de los valores reales y predichos sobre las barras
for p in ax.patches:
    # Obtener la posición de la barra
    height = p.get_height()
    width = p.get_width()
    x_position = p.get_x() + width / 2

    # Obtener los valores reales y predichos
    valor_real = p.get_x()  # x es la posición de la barra en el eje x
    valor_predicho = height  # el valor predicho está en el eje y

    # Mostrar los valores
    ax.text(x_position, height + 0.02, f"Real: {int(valor_real)}\nPred: {int(valor_predicho)}", 
            horizontalalignment='center', verticalalignment='bottom', fontsize=9)

# Agregar título y etiquetas
plt.title("Comparación de Valores Reales vs Predicciones por Modelo")
plt.xlabel("Valor Real")
plt.ylabel("Valor Predicho")
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# El modelo seleccionado es "Decision Tree"

# %% [markdown]
# ### Generar joblib
# ([Volver al Inicio](#Modelo))

# %% [markdown]
# Con base a lo anterior, se guardan los modelos respectivos, sin embargo, se enuncia que el modelo a ser usado para el despligue corresponde al de "Decision Tree", correspondiente a `clf_model.joblib`

# %%
# Se procede a guardar el modelo de regresion
joblib.dump(regression, '../../deploy/lr_model.joblib')
# Out:
# ['../../deploy/lr_model.joblib']

# %%
# Se procede a guardar el modelo de Decision Tree
joblib.dump(rf, '../../deploy/clf_model.joblib')
# Out:
# ['../../deploy/clf_model.joblib']

# %%
# Se procede a guardar el modelo de Random Forest 
joblib.dump(rf, '../../deploy/rf_model.joblib')
# Out:
# ['../../deploy/rf_model.joblib']

# %% [markdown]
# ## Equivalencia Datos
# ([Volver al Inicio](#Modelo))

# %% [markdown]
# Con el fin de revisar a que equivalencias pertencen los datos, se hace el cruce con la divipola y los codigos de programas

# %%
# Visualización de datos que corresponden a DESERCION
data[data['target']==0]
# Out:
#       ESTRATO  SEMESTRE  PROMEDIOSEMESTRE  EDAD2  PROGRAMA  GENERO  CIUDADRESIDENCIA  CIUDADNACIMIENTO  target
# 34       2.00         8              3.10     25    102383       0          76275.00          76275.00       0
# 139      2.00         6              4.00     19    102383       0          19698.00          19698.00       0
# 186      3.00         4              4.00     40    102383       1          76001.00          76001.00       0
# 221      1.00         3              3.20     23    102383       1          76001.00          76001.00       0
# 242      5.00         6              3.80     34    102383       0          76001.00          76001.00       0
# ...       ...       ...               ...    ...       ...     ...               ...               ...     ...
# 9284     3.00         1              4.30     25     90555       1          76001.00          76001.00       0
# 9297     3.00         1              3.70     20     90555       1          76001.00          76001.00       0
# 9306     1.00         1              3.80     18     90555       1          76001.00          76001.00       0
# 9334     2.00         1              3.40     21     90555       1          76001.00          76001.00       0
# 9346     3.00         1              4.40     33     90555       1          76001.00          19001.00       0
#
# [1231 rows x 9 columns]

# %%
# Se carga la información de programas
programa = pd.read_csv('../raw/programas.csv', sep=",", encoding='utf-8')
programa.rename(columns={'PROGRAMA':'NOMBRE_PROGRAMA'}, inplace=True)
programa
# Out:
#    CODIGOPROGRAMA                      NOMBRE_PROGRAMA
# 0           53212                              DEPORTE
# 1            7306                         FISIOTERAPIA
# 2            7305                TECNOLOGIA EN DEPORTE
# 3          102383                NUTRICION Y DIETETICA
# 4          104024                  TERAPIA OCUPACIONAL
# 5           90555           ADMINISTRACION DE EMPRESAS
# 6          110571      TECNOLOGÍA EN GESTIÓN DEPORTIVA
# 7          110783  MERCADEO Y NEGOCIOS INTERNACIONALES

# %%
# Se carga la información de DIVIPOLA
divipola = pd.read_csv('../raw/DIVIPOLA-_C_digos_municipios_20241127.csv', sep=",", encoding='utf-8')
divipola
# Out:
#       Codigo_Departamento  Codigo_Municipio Nombre_Departamento Nombre_Municipio                    Tipo
# 0                       5              5001           ANTIOQUIA         MEDELLÍN               Municipio
# 1                       5              5002           ANTIOQUIA        ABEJORRAL               Municipio
# 2                       5              5004           ANTIOQUIA         ABRIAQUÍ               Municipio
# 3                       5              5021           ANTIOQUIA       ALEJANDRÍA               Municipio
# 4                       5              5030           ANTIOQUIA            AMAGÁ               Municipio
# ...                   ...               ...                 ...              ...                     ...
# 1116                   97             97889              VAUPÉS         YAVARATÉ  Área no municipalizada
# 1117                   99             99001             VICHADA   PUERTO CARREÑO               Municipio
# 1118                   99             99524             VICHADA     LA PRIMAVERA               Municipio
# 1119                   99             99624             VICHADA    SANTA ROSALÍA               Municipio
# 1120                   99             99773             VICHADA         CUMARIBO               Municipio
#
# [1121 rows x 5 columns]

# %%
# Cruce información con programas
relacion = pd.merge(data, 
                    programa, 
                    left_on='PROGRAMA', 
                    right_on='CODIGOPROGRAMA', 
                    how='left')

# %%
# Cruce informacion ciudad residencia
relacion = pd.merge(relacion, 
                    divipola[['Codigo_Municipio','Nombre_Municipio']], 
                    left_on='CIUDADRESIDENCIA', 
                    right_on='Codigo_Municipio', 
                    how='left').rename(
    columns={ 
        'Codigo_Municipio': 'COD_CIUDADRESIDENCIA', 
        'Nombre_Municipio': 'Nombre_CIUDADRESIDENCIA'}
)

# %%
# Cruce informacion ciudad nacimiento
relacion = pd.merge(relacion, 
                    divipola[['Codigo_Municipio','Nombre_Municipio']], 
                    left_on='CIUDADNACIMIENTO', 
                    right_on='Codigo_Municipio', 
                    how='left').rename(
    columns={ 
        'Codigo_Municipio': 'COD_CIUDADNACIMIENTO', 
        'Nombre_Municipio': 'Nombre_CIUDADNACIMIENTO'}
)

# %%
genero_map = {1:'Masculino', 0:'Femenino'}
relacion['DESC_GENERO'] = relacion['GENERO'].map(genero_map)

# %%
relacion[relacion['target']==0].sample(3)
# Out:
#       ESTRATO  SEMESTRE  PROMEDIOSEMESTRE  EDAD2  PROGRAMA  GENERO  CIUDADRESIDENCIA  CIUDADNACIMIENTO  target  CODIGOPROGRAMA NOMBRE_PROGRAMA  COD_CIUDADRESIDENCIA Nombre_CIUDADRESIDENCIA  COD_CIUDADNACIMIENTO Nombre_CIUDADNACIMIENTO DESC_GENERO
# 4189     1.00         1              3.80     18     53212       1          76001.00          76001.00       0           53212         DEPORTE                 76001                    CALI                 76001                    CALI   Masculino
# 7632     3.00         1              3.70     19      7306       1          76001.00          76001.00       0            7306    FISIOTERAPIA                 76001                    CALI                 76001                    CALI   Masculino
# 2783     3.00         4              2.50     21     53212       1          76001.00          76001.00       0           53212         DEPORTE                 76001                    CALI                 76001                    CALI   Masculino
