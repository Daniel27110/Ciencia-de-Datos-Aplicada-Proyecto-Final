# %% [markdown]
# # ENDEPORTE_PROYECTO_FINAL
#
# ### Objetivo:
# Mediante tecnicas de machine learning establecer las variables que mayor relacion tienen con la desercion e identificar los estudiantes de carreras profesionales o tecnologicas de la entidad que pueden desertar o no de sus programas.
#
# ### Contexto del negocio
# Para la entidad es dificil identificar tempranamente los estudiantes que están en riesgo de abandonar sus carreras, las intervenciones son a menudo menos efectivas porque las señales de riesgo no aparecen hasta que el estudiante ya ha tomado la decisión de desertar. Se espera que mediante modelos de machine learning se identifiquen con anticipacion los estudiantes que pueden llegar a desertar con el fin de brindar a cada estudiante el tipo y nivel de apoyo que necesita para superar sus dificultades.

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\diego\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\diego\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.26.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\diego\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\diego\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\diego\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import unicodedata
import warnings

warnings.filterwarnings('ignore')
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
from sklearn.preprocessing import LabelEncoder # Import LabelEncoder

# %% [markdown]
# ##**1. Entendimiento y preparación de los datos:**

# %% [markdown]
# ### Cargue del dataset

# %%
demograficos_url="https://github.com/amrios80/Endeporte/raw/refs/heads/main/data/Demograficos.csv.gz"
historicos_url="https://github.com/amrios80/Endeporte/raw/refs/heads/main/data/HistoricoNotas.csv.gz"

demograficos_df = pd.read_csv(demograficos_url, sep=";", compression='gzip')
historicos_df=pd.read_csv(historicos_url, sep=";", compression="gzip")

# %%
divipola = pd.read_csv('../raw/DIVIPOLA-_C_digos_municipios_20241127.csv', sep=",", encoding='utf-8')

# %% [markdown]
# ### Limpieza de datos

# %% [markdown]
# * ***Estandarizacion*** : Segun las reglas acordadas con ENDEPORTE, Se excluyen del estudio las ESPECIALIZACIONES:

# %%
demograficos_df.sample(3)
# Out:
#       PERIODO_ACAENICO        CODIGO                        UNIDAD  \
# 50897         2024 - 1  104024231106  ESCUELA NACIONAL DEL DEPORTE
# 20512        2019 - 2T   7305192T190  ESCUELA NACIONAL DEL DEPORTE
# 47929         2023 - 2  102383202091  ESCUELA NACIONAL DEL DEPORTE
#
#        CODIGOPROGRAMA               PROGRAMA  SEMESTRE PROMEDIOSEMESTRE  \
# 50897          104024    TERAPIA OCUPACIONAL         3              3,6
# 20512            7305  TECNOLOGIA EN DEPORTE         1              3,2
# 47929          102383  NUTRICION Y DIETETICA         7              3,9
#
#           GENERO FECHANACIMIENTO  ESTRATO CIUDADRESIDENCIA  \
# 50897   Femenino      10-02-2004      1.0             CALI
# 20512  Masculino      21-12-1990      3.0             CALI
# 47929   Femenino      08-05-2003      3.0           TUMACO
#
#       DEPARTAMENTORESICEDENCIA ESTADOCIVIL PROMEDIOGENERAL  \
# 50897          VALLE DEL CAUCA     Soltero             3,7
# 20512          VALLE DEL CAUCA     Soltero             3,2
# 47929                   NARIÑO     Soltero             4,2
#
#                  SITUACION_ACTUAL                  CATEGORIA_ACTUAL  \
# 50897                      ACTIVO                           ANTIGUO
# 20512  BAJO RENDIMIENTO ACADEMICO                           ANTIGUO
# 47929                      ACTIVO  CONTINUIDAD ACADEMICA - EGRESADO
#
#             SITUACION_DEL_PERIODO CATEGORIA_DEL_PERIODO DISCAPACIDAD  \
# 50897                      ACTIVO               ANTIGUO      NINGUNA
# 20512  BAJO RENDIMIENTO ACADEMICO               ANTIGUO      NINGUNA
# 47929                      ACTIVO               ANTIGUO      NINGUNA
#
#       TIPO_DISCAPACIDAD FECHA_MATRICULA  IDCIUDADNACIMIENTO CIUDADNACIMIENTO  \
# 50897           NINGUNA        03/01/24             76001.0             CALI
# 20512           NINGUNA        29/08/19             76001.0             CALI
# 47929           NINGUNA        05/07/23             52480.0           NARIÑO
#
#        IDDEPARTAMENTONACIMIENTO DEPARTAMENTONACIMIENTO  SISBEN  NIVELSISBEN  \
# 50897                      76.0        VALLE DEL CAUCA     0.0          NaN
# 20512                      76.0        VALLE DEL CAUCA     0.0          NaN
# 47929                      52.0                 NARIÑO     1.0          1.0
#
#        CANTIDAD  PERIODO  EDAD2                     EDAD      FACULTAD  \
# 50897         1   2024-I     20  Edad entre 18 y 25 años    Fac. Salud
# 20512         1  2019-II     29  Edad entre 26 y 33 años  Fac. Deporte
# 47929         1  2023-II     20  Edad entre 18 y 25 años    Fac. Salud
#
#       NIVEL_FORMACION
# 50897  Universitrario
# 20512     Tecnológico
# 47929  Universitrario

# %%
demograficos_df["NIVEL_FORMACION"].value_counts()
# Out:
# NIVEL_FORMACION
# Universitrario     48022
# Tecnológico         4994
# Especialización     2403
# Name: count, dtype: int64

# %%
demograficos_df=demograficos_df[(demograficos_df["NIVEL_FORMACION"] != "Especialización")]

# %% [markdown]
# *  ***Eliminacion de codigos de estudiantes duplicados*** : La informacion demografica debe estar a nivel de estudiante, segun lo definido con la entidad, se valida que no haya duplicidad a nivel de codigo del estudiante.

# %%
total_rows = demograficos_df.shape[0]
total_rows
# Out:
# 53016

# %%
demograficos_df.loc[demograficos_df.duplicated(subset=["CODIGO"], keep=False)].sample(3)
# Out:
#       PERIODO_ACAENICO        CODIGO                        UNIDAD  \
# 44952         2023 - 1  102383162208  ESCUELA NACIONAL DEL DEPORTE
# 22054         2020 - 1  104024171027  ESCUELA NACIONAL DEL DEPORTE
# 43200         2022 - 2   90555222130  ESCUELA NACIONAL DEL DEPORTE
#
#        CODIGOPROGRAMA                    PROGRAMA  SEMESTRE PROMEDIOSEMESTRE  \
# 44952          102383       NUTRICION Y DIETETICA         8              3,2
# 22054          104024         TERAPIA OCUPACIONAL         7              4,6
# 43200           90555  ADMINISTRACION DE EMPRESAS         1              4,7
#
#           GENERO FECHANACIMIENTO  ESTRATO CIUDADRESIDENCIA  \
# 44952   Femenino      01-06-1998      1.0           CALOTO
# 22054  Masculino      25-03-1999      2.0            VIJES
# 43200  Masculino      19-10-2000      2.0             CALI
#
#       DEPARTAMENTORESICEDENCIA ESTADOCIVIL PROMEDIOGENERAL  \
# 44952                    CAUCA     Soltero             3,4
# 22054          VALLE DEL CAUCA     Soltero             4,1
# 43200          VALLE DEL CAUCA     Soltero             4,7
#
#                     SITUACION_ACTUAL                  CATEGORIA_ACTUAL  \
# 44952                         ACTIVO                           ANTIGUO
# 22054  EXCLUIDO CANCELACION SEMESTRE  CONTINUIDAD ACADEMICA - EGRESADO
# 43200                         ACTIVO                           ANTIGUO
#
#       SITUACION_DEL_PERIODO CATEGORIA_DEL_PERIODO DISCAPACIDAD  \
# 44952                ACTIVO               ANTIGUO      NINGUNA
# 22054                ACTIVO               ANTIGUO      NINGUNA
# 43200                ACTIVO               ANTIGUO      NINGUNA
#
#       TIPO_DISCAPACIDAD FECHA_MATRICULA  IDCIUDADNACIMIENTO  \
# 44952           NINGUNA        15/01/23             19698.0
# 22054           NINGUNA        27/01/20             76001.0
# 43200           NINGUNA        27/07/22             76001.0
#
#              CIUDADNACIMIENTO  IDDEPARTAMENTONACIMIENTO  \
# 44952  SANTANDER DE QUILICHAO                      19.0
# 22054                    CALI                      76.0
# 43200                    CALI                      76.0
#
#       DEPARTAMENTONACIMIENTO  SISBEN  NIVELSISBEN  CANTIDAD  PERIODO  EDAD2  \
# 44952                  CAUCA     1.0          1.0         1   2023-I     25
# 22054        VALLE DEL CAUCA     0.0          NaN         1   2020-I     21
# 43200        VALLE DEL CAUCA     0.0          NaN         1  2022-II     22
#
#                           EDAD    FACULTAD NIVEL_FORMACION
# 44952  Edad entre 18 y 25 años  Fac. Salud  Universitrario
# 22054  Edad entre 18 y 25 años  Fac. Salud  Universitrario
# 43200  Edad entre 18 y 25 años  Fac. Admon  Universitrario

# %%
demograficos_df[demograficos_df["CODIGO"]=="102383181022"].sort_values(by="PERIODO_ACAENICO",ascending=False).head(3)
# Out:
#       PERIODO_ACAENICO        CODIGO                        UNIDAD  \
# 38163         2022 - 1  102383181022  ESCUELA NACIONAL DEL DEPORTE
# 34325         2021 - 2  102383181022  ESCUELA NACIONAL DEL DEPORTE
# 30500         2021 - 1  102383181022  ESCUELA NACIONAL DEL DEPORTE
#
#        CODIGOPROGRAMA               PROGRAMA  SEMESTRE PROMEDIOSEMESTRE  \
# 38163          102383  NUTRICION Y DIETETICA         7              4,6
# 34325          102383  NUTRICION Y DIETETICA         8              4,2
# 30500          102383  NUTRICION Y DIETETICA         7              4,4
#
#          GENERO FECHANACIMIENTO  ESTRATO CIUDADRESIDENCIA  \
# 38163  Femenino      06-04-2000      3.0             CALI
# 34325  Femenino      06-04-2000      3.0             CALI
# 30500  Femenino      06-04-2000      3.0             CALI
#
#       DEPARTAMENTORESICEDENCIA ESTADOCIVIL PROMEDIOGENERAL  \
# 38163          VALLE DEL CAUCA     Soltero             4,2
# 34325          VALLE DEL CAUCA     Soltero             4,1
# 30500          VALLE DEL CAUCA     Soltero             3,9
#
#                           SITUACION_ACTUAL                  CATEGORIA_ACTUAL  \
# 38163  EXCLUIDO NO RENOVACION DE MATRICULA  CONTINUIDAD ACADEMICA - EGRESADO
# 34325  EXCLUIDO NO RENOVACION DE MATRICULA  CONTINUIDAD ACADEMICA - EGRESADO
# 30500  EXCLUIDO NO RENOVACION DE MATRICULA  CONTINUIDAD ACADEMICA - EGRESADO
#
#       SITUACION_DEL_PERIODO CATEGORIA_DEL_PERIODO DISCAPACIDAD  \
# 38163                ACTIVO               ANTIGUO      NINGUNA
# 34325                ACTIVO               ANTIGUO      NINGUNA
# 30500                ACTIVO               ANTIGUO      NINGUNA
#
#       TIPO_DISCAPACIDAD FECHA_MATRICULA  IDCIUDADNACIMIENTO CIUDADNACIMIENTO  \
# 38163           NINGUNA        16/02/22             76001.0             CALI
# 34325           NINGUNA        30/07/21             76001.0             CALI
# 30500           NINGUNA        12/01/21             76001.0             CALI
#
#        IDDEPARTAMENTONACIMIENTO DEPARTAMENTONACIMIENTO  SISBEN  NIVELSISBEN  \
# 38163                      76.0        VALLE DEL CAUCA     0.0          NaN
# 34325                      76.0        VALLE DEL CAUCA     0.0          NaN
# 30500                      76.0        VALLE DEL CAUCA     0.0          NaN
#
#        CANTIDAD  PERIODO  EDAD2                     EDAD    FACULTAD  \
# 38163         1   2022-I     22  Edad entre 18 y 25 años  Fac. Salud
# 34325         1  2021-II     21  Edad entre 18 y 25 años  Fac. Salud
# 30500         1   2021-I     21  Edad entre 18 y 25 años  Fac. Salud
#
#       NIVEL_FORMACION
# 38163  Universitrario
# 34325  Universitrario
# 30500  Universitrario

# %% [markdown]
# Se observa que el codigo de estudiante se repite tantas veces como periodos académicos haya cursado y las variables de semestre, promediosemestre, promediogeneral y fecha_matricula son las correspondientes al periodo academico, las demas variables demograficas son las mismas para todos los periodos academicos. Por lo anterior, se tomara la informacion demografica correspondiente al ultimo periodo academico.

# %%
idx = demograficos_df.groupby('CODIGO')['PERIODO_ACAENICO'].idxmax()

# %%
max_periodo_rows = demograficos_df.loc[idx]

# %%
demograficos_df_uniq=max_periodo_rows.copy()

# %%
total_rows_uniq = demograficos_df_uniq.shape[0]
total_rows_uniq
# Out:
# 10021

# %% [markdown]
# El estudio se realizara con la informacion demografica correspondiente al ultimo periodo academico de 10.021 estudiantes unicos.

# %% [markdown]
# *  ***Calculo de la variable objetivo (Desercion)*** : Si la variable denominada “situación actual” contiene cumple las siguientes condiciones “excluido cancelación semestre” o “excluido no renovación matricula” o “retiro definitivo” y la variable denominada “categoría actual” el valor es diferente de “continuidad académica - egresado” se considera “Deserción”.

# %%
def calculate_target(row):
    if (row['SITUACION_ACTUAL'] == 'EXCLUIDO NO RENOVACION DE MATRICULA' or row["SITUACION_ACTUAL"]=='RETIRO DEFINITIVO' or row["SITUACION_ACTUAL"]=='EXCLUIDO CANCELACION SEMESTRE' ) and  (row['CATEGORIA_ACTUAL'] != "CONTINUIDAD ACADEMICA - EGRESADO") :
        return 0
    else:
        return 1

# %%
demograficos_df_uniq["target"]=demograficos_df_uniq.apply(calculate_target, axis=1)

# %%
demograficos_df_uniq["target"].value_counts()
# Out:
# target
# 1    8760
# 0    1261
# Name: count, dtype: int64

# %% [markdown]
# Se observa que 1.261 estudiantes de 10.021 desertan, es decir la tasa de desercion de la poblacion estudiada es de 12,6% valor que coincide con las cifras de desercion reportadas por la entidad.

# %% [markdown]
# * ***Creacion del dataset (features + target) :*** De acuerdo al analisis exploratorio desarrollado para la primera entrega, se tendran en cuenta para el estudio las siguientes variables, dada su relacion directa con la desercion (target): ESTRATO, SEMESTRE, PROMEDIOSEMESTRE, EDAD2, PROGRAMA, GENERO, CIUDADRESIDENCIA, CIUDADNACIMIENTO. Con base en estas variables de entrada se creara el dataset previa conversion numerica de las variables: ESTRATO, SEMESTRE, PROMEDIOSEMESTRE, EDAD2 y codificacion de las variables categoricas: PROGRAMA, GENERO, CIUDADRESIDENCIA, CIUDADNACIMIENTO.

# %% [markdown]
# Conversion a valor numerico del ESTRATO, SEMESTRE, PROMEDIOSEMESTRE Y EDAD2

# %%
field="ESTRATO"
demograficos_df_uniq[field] = pd.to_numeric(demograficos_df_uniq[field], errors='coerce')
field="SEMESTRE"
demograficos_df_uniq[field] = pd.to_numeric(demograficos_df_uniq[field], errors='coerce')
field="PROMEDIOSEMESTRE"
demograficos_df_uniq[field] = demograficos_df_uniq[field].astype(str).str.replace(',', '.', regex=False)
demograficos_df_uniq[field] = pd.to_numeric(demograficos_df_uniq[field], errors='coerce')
field="EDAD2"
demograficos_df_uniq[field] = pd.to_numeric(demograficos_df_uniq[field], errors='coerce')

# %%
demograficos_df_uniq.sample(3)
# Out:
#       PERIODO_ACAENICO        CODIGO                        UNIDAD  \
# 47486         2023 - 2   53212202199  ESCUELA NACIONAL DEL DEPORTE
# 32861         2021 - 2  102383172147  ESCUELA NACIONAL DEL DEPORTE
# 46081         2023 - 1   53212182127  ESCUELA NACIONAL DEL DEPORTE
#
#        CODIGOPROGRAMA               PROGRAMA  SEMESTRE  PROMEDIOSEMESTRE  \
# 47486           53212                DEPORTE         6               3.9
# 32861          102383  NUTRICION Y DIETETICA         7               4.2
# 46081           53212                DEPORTE         8               3.9
#
#           GENERO FECHANACIMIENTO  ESTRATO        CIUDADRESIDENCIA  \
# 47486   Femenino      30-03-2001      2.0                    CALI
# 32861   Femenino      03-04-1999      3.0  SANTANDER DE QUILICHAO
# 46081  Masculino      20-08-2000      1.0                    CALI
#
#       DEPARTAMENTORESICEDENCIA ESTADOCIVIL PROMEDIOGENERAL  \
# 47486          VALLE DEL CAUCA     Soltero               4
# 32861                    CAUCA     Soltero             3,7
# 46081          VALLE DEL CAUCA     Soltero             3,6
#
#                           SITUACION_ACTUAL                  CATEGORIA_ACTUAL  \
# 47486                               ACTIVO                         REINGRESO
# 32861  EXCLUIDO NO RENOVACION DE MATRICULA  CONTINUIDAD ACADEMICA - EGRESADO
# 46081  EXCLUIDO NO RENOVACION DE MATRICULA  CONTINUIDAD ACADEMICA - EGRESADO
#
#       SITUACION_DEL_PERIODO CATEGORIA_DEL_PERIODO           DISCAPACIDAD  \
# 47486                ACTIVO               ANTIGUO  DISCAPACIDAD AUDITIVA
# 32861                ACTIVO               ANTIGUO                NINGUNA
# 46081                ACTIVO               ANTIGUO                NINGUNA
#
#                          TIPO_DISCAPACIDAD FECHA_MATRICULA  \
# 47486  DISCAPACIDAD SENSORIAL - HIPOACUSIA        04/07/23
# 32861                              NINGUNA        15/07/21
# 46081                              NINGUNA        23/12/22
#
#        IDCIUDADNACIMIENTO        CIUDADNACIMIENTO  IDDEPARTAMENTONACIMIENTO  \
# 47486             76001.0                    CALI                      76.0
# 32861             19698.0  SANTANDER DE QUILICHAO                      19.0
# 46081             52473.0                MOSQUERA                      52.0
#
#       DEPARTAMENTONACIMIENTO  SISBEN  NIVELSISBEN  CANTIDAD  PERIODO  EDAD2  \
# 47486        VALLE DEL CAUCA     0.0          NaN         1  2023-II     22
# 32861                  CAUCA     0.0          NaN         1  2021-II     22
# 46081                 NARIÑO     1.0          1.0         1   2023-I     22
#
#                           EDAD      FACULTAD NIVEL_FORMACION  target
# 47486  Edad entre 18 y 25 años  Fac. Deporte  Universitrario       1
# 32861  Edad entre 18 y 25 años    Fac. Salud  Universitrario       1
# 46081  Edad entre 18 y 25 años  Fac. Deporte  Universitrario       1

# %%
# Función para eliminar tildes de los textos
def quitar_tildes(texto):
    # Asegurarse de que el texto sea una cadena
    if isinstance(texto, str):
        return ''.join(
            c for c in unicodedata.normalize('NFD', texto) if unicodedata.category(c) != 'Mn'
        )
    return texto  # Si no es una cadena, retornar el valor tal cual (puede ser NaN, float, etc.)

# %%
# Aplicar la función de quitar tildes a las columnas relevantes de ambos DataFrames
demograficos_df_uniq['CIUDADRESIDENCIA'] = demograficos_df_uniq['CIUDADRESIDENCIA'].apply(quitar_tildes)
divipola['Nombre_Municipio'] = divipola['Nombre_Municipio'].apply(quitar_tildes)

# %%
relacion = pd.merge(demograficos_df_uniq, 
                    divipola[['Codigo_Municipio','Nombre_Municipio']], 
                    left_on='CIUDADRESIDENCIA', 
                    right_on='Nombre_Municipio', 
                    how='left').rename(
    columns={ 
        'Codigo_Municipio': 'COD_CIUDADRESIDENCIA', 
        'Nombre_Municipio': 'Nombre_CIUDADRESIDENCIA'}
)

relacion = pd.merge(relacion, 
                    divipola[['Codigo_Municipio','Nombre_Municipio']], 
                    left_on='IDCIUDADNACIMIENTO', 
                    right_on='Codigo_Municipio', 
                    how='left').rename(
    columns={ 
        'Codigo_Municipio': 'COD_CIUDADNACIMIENTO', 
        'Nombre_Municipio': 'Nombre_CIUDADNACIMIENTO'}
)
relacion.sample(3)
# Out:
#      PERIODO_ACAENICO       CODIGO                           UNIDAD  \
# 5444         2024 - 1  53212231301     ESCUELA NACIONAL DEL DEPORTE
# 3870         2021 - 1  53212172344     ESCUELA NACIONAL DEL DEPORTE
# 6696        2024 - 1G  7305221G027  CERES SALTO AFRO GUACHENE CAUCA
#
#       CODIGOPROGRAMA               PROGRAMA  SEMESTRE  PROMEDIOSEMESTRE  \
# 5444           53212                DEPORTE         3               0.4
# 3870           53212                DEPORTE         8               4.8
# 6696            7305  TECNOLOGIA EN DEPORTE         5               3.7
#
#          GENERO FECHANACIMIENTO  ESTRATO CIUDADRESIDENCIA  \
# 5444  Masculino      30-06-1998      3.0             CALI
# 3870   Femenino      15-09-1995      3.0             CALI
# 6696  Masculino      19-01-2000      3.0       CANDELARIA
#
#      DEPARTAMENTORESICEDENCIA ESTADOCIVIL PROMEDIOGENERAL  \
# 5444          VALLE DEL CAUCA     Soltero               3
# 3870          VALLE DEL CAUCA     Soltero             4,4
# 6696          VALLE DEL CAUCA     Soltero             3,5
#
#                          SITUACION_ACTUAL                  CATEGORIA_ACTUAL  \
# 5444           BAJO RENDIMIENTO ACADEMICO                           ANTIGUO
# 3870  EXCLUIDO NO RENOVACION DE MATRICULA  CONTINUIDAD ACADEMICA - EGRESADO
# 6696                               ACTIVO                           ANTIGUO
#
#            SITUACION_DEL_PERIODO CATEGORIA_DEL_PERIODO DISCAPACIDAD  \
# 5444  BAJO RENDIMIENTO ACADEMICO               ANTIGUO      NINGUNA
# 3870                      ACTIVO               ANTIGUO      NINGUNA
# 6696                      ACTIVO               ANTIGUO      NINGUNA
#
#      TIPO_DISCAPACIDAD FECHA_MATRICULA  IDCIUDADNACIMIENTO CIUDADNACIMIENTO  \
# 5444           NINGUNA        02/01/24             76001.0             CALI
# 3870           NINGUNA        28/01/21             76001.0             CALI
# 6696           NINGUNA        01/02/24             76001.0             CALI
#
#       IDDEPARTAMENTONACIMIENTO DEPARTAMENTONACIMIENTO  SISBEN  NIVELSISBEN  \
# 5444                      76.0        VALLE DEL CAUCA     0.0          NaN
# 3870                      76.0        VALLE DEL CAUCA     0.0          NaN
# 6696                      76.0        VALLE DEL CAUCA     1.0          1.0
#
#       CANTIDAD PERIODO  EDAD2                     EDAD      FACULTAD  \
# 5444         1  2024-I     26  Edad entre 26 y 33 años  Fac. Deporte
# 3870         1  2021-I     26  Edad entre 26 y 33 años  Fac. Deporte
# 6696         1  2024-I     24  Edad entre 18 y 25 años  Fac. Deporte
#
#      NIVEL_FORMACION  target  COD_CIUDADRESIDENCIA Nombre_CIUDADRESIDENCIA  \
# 5444  Universitrario       1               76001.0                    CALI
# 3870  Universitrario       1               76001.0                    CALI
# 6696     Tecnológico       1                8141.0              CANDELARIA
#
#       COD_CIUDADNACIMIENTO Nombre_CIUDADNACIMIENTO
# 5444               76001.0                    CALI
# 3870               76001.0                    CALI
# 6696               76001.0                    CALI

# %%
# Revision de cruces
relacion[relacion['CIUDADRESIDENCIA']=='GUACHENE'].sample(3)
# Out:
#      PERIODO_ACAENICO        CODIGO                        UNIDAD  \
# 2068         2024 - 1  110783232092  ESCUELA NACIONAL DEL DEPORTE
# 6186        2018 - 1T   7305172T316  ESCUELA NACIONAL DEL DEPORTE
# 5584         2024 - 1   53212232439  ESCUELA NACIONAL DEL DEPORTE
#
#       CODIGOPROGRAMA                             PROGRAMA  SEMESTRE  \
# 2068          110783  MERCADEO Y NEGOCIOS INTERNACIONALES         2
# 6186            7305                TECNOLOGIA EN DEPORTE         2
# 5584           53212                              DEPORTE         2
#
#       PROMEDIOSEMESTRE     GENERO FECHANACIMIENTO  ESTRATO CIUDADRESIDENCIA  \
# 2068               4.1  Masculino      16-05-2006      1.0         GUACHENE
# 6186               3.0  Masculino      06-06-1998      1.0         GUACHENE
# 5584               3.9  Masculino      20-09-2005      1.0         GUACHENE
#
#      DEPARTAMENTORESICEDENCIA ESTADOCIVIL PROMEDIOGENERAL  \
# 2068                    CAUCA     Soltero             4,1
# 6186                    CAUCA     Soltero             3,4
# 5584                    CAUCA     Soltero             3,6
#
#                          SITUACION_ACTUAL CATEGORIA_ACTUAL  \
# 2068                               ACTIVO          ANTIGUO
# 6186  EXCLUIDO NO RENOVACION DE MATRICULA          ANTIGUO
# 5584                               ACTIVO          ANTIGUO
#
#      SITUACION_DEL_PERIODO CATEGORIA_DEL_PERIODO DISCAPACIDAD  \
# 2068                ACTIVO               ANTIGUO      NINGUNA
# 6186                ACTIVO               ANTIGUO      NINGUNA
# 5584                ACTIVO               ANTIGUO      NINGUNA
#
#      TIPO_DISCAPACIDAD FECHA_MATRICULA  IDCIUDADNACIMIENTO CIUDADNACIMIENTO  \
# 2068           NINGUNA        02/01/24             19300.0         GUACHENE
# 6186           NINGUNA        15/01/18             19300.0         GUACHENE
# 5584           NINGUNA        03/01/24             76001.0             CALI
#
#       IDDEPARTAMENTONACIMIENTO DEPARTAMENTONACIMIENTO  SISBEN  NIVELSISBEN  \
# 2068                      19.0                  CAUCA     0.0          NaN
# 6186                      19.0                  CAUCA     1.0          1.0
# 5584                      76.0        VALLE DEL CAUCA     0.0          NaN
#
#       CANTIDAD PERIODO  EDAD2                     EDAD      FACULTAD  \
# 2068         1  2024-I     18  Edad entre 18 y 25 años    Fac. Admon
# 6186         1  2018-I     20  Edad entre 18 y 25 años  Fac. Deporte
# 5584         1  2024-I     19  Edad entre 18 y 25 años  Fac. Deporte
#
#      NIVEL_FORMACION  target  COD_CIUDADRESIDENCIA Nombre_CIUDADRESIDENCIA  \
# 2068  Universitrario       1               19300.0                GUACHENE
# 6186     Tecnológico       0               19300.0                GUACHENE
# 5584  Universitrario       1               19300.0                GUACHENE
#
#       COD_CIUDADNACIMIENTO Nombre_CIUDADNACIMIENTO
# 2068               19300.0                GUACHENE
# 6186               19300.0                GUACHENE
# 5584               76001.0                    CALI

# %%
# Revision de Genero
relacion['GENERO'].unique()
# Out:
# array(['Masculino', 'Femenino'], dtype=object)

# %%
# Mapeo de valores de genero
genero_map = {'Masculino': 1, 'Femenino': 0}

# %%
relacion['GENERO'] = relacion['GENERO'].str.strip() # Eliminar espacios
relacion['GENERO'] = relacion['GENERO'].str.title()  # Convertir a formato de título (Primera letra en mayúscula)

# %%
# MAPEO DE VALORES NUMERICOS DE GENERO
relacion['GENERO'] = relacion['GENERO'].map(genero_map)
relacion.sample(5)
# Out:
#      PERIODO_ACAENICO       CODIGO                        UNIDAD  \
# 3532         2021 - 2  53212171015  ESCUELA NACIONAL DEL DEPORTE
# 9978         2024 - 1  90555212192  ESCUELA NACIONAL DEL DEPORTE
# 9052         2024 - 1   7306232267  ESCUELA NACIONAL DEL DEPORTE
# 8686         2024 - 1   7306211334  ESCUELA NACIONAL DEL DEPORTE
# 2996         2017 - 1  53212151291  ESCUELA NACIONAL DEL DEPORTE
#
#       CODIGOPROGRAMA                    PROGRAMA  SEMESTRE  PROMEDIOSEMESTRE  \
# 3532           53212                     DEPORTE         8               4.0
# 9978           90555  ADMINISTRACION DE EMPRESAS         4               3.2
# 9052            7306                FISIOTERAPIA         2               3.7
# 8686            7306                FISIOTERAPIA         7               3.7
# 2996           53212                     DEPORTE         5               2.9
#
#       GENERO FECHANACIMIENTO  ESTRATO CIUDADRESIDENCIA  \
# 3532       0      09-10-1999      4.0             CALI
# 9978       0      09-09-2000      2.0             CALI
# 9052       0      13-12-2003      3.0             CALI
# 8686       0      13-04-2003      1.0          PRADERA
# 2996       1      14-03-1995      2.0             CALI
#
#      DEPARTAMENTORESICEDENCIA ESTADOCIVIL PROMEDIOGENERAL  \
# 3532          VALLE DEL CAUCA     Soltero             3,8
# 9978          VALLE DEL CAUCA     Soltero             3,2
# 9052          VALLE DEL CAUCA     Soltero             3,8
# 8686          VALLE DEL CAUCA     Soltero             3,9
# 2996          VALLE DEL CAUCA     Soltero             3,3
#
#                          SITUACION_ACTUAL                  CATEGORIA_ACTUAL  \
# 3532  EXCLUIDO NO RENOVACION DE MATRICULA  CONTINUIDAD ACADEMICA - EGRESADO
# 9978                               ACTIVO                           ANTIGUO
# 9052                               ACTIVO                           ANTIGUO
# 8686                               ACTIVO                           ANTIGUO
# 2996  EXCLUIDO NO RENOVACION DE MATRICULA                           ANTIGUO
#
#            SITUACION_DEL_PERIODO CATEGORIA_DEL_PERIODO DISCAPACIDAD  \
# 3532                      ACTIVO               ANTIGUO      NINGUNA
# 9978                      ACTIVO               ANTIGUO      NINGUNA
# 9052                      ACTIVO               ANTIGUO      NINGUNA
# 8686                      ACTIVO               ANTIGUO      NINGUNA
# 2996  BAJO RENDIMIENTO ACADEMICO               ANTIGUO      NINGUNA
#
#      TIPO_DISCAPACIDAD FECHA_MATRICULA  IDCIUDADNACIMIENTO CIUDADNACIMIENTO  \
# 3532           NINGUNA        29/07/21             76001.0             CALI
# 9978           NINGUNA        13/01/24             76001.0             CALI
# 9052           NINGUNA        02/01/24             76001.0             CALI
# 8686           NINGUNA        02/01/24             11001.0      BOGOTA D.C.
# 2996           NINGUNA        11/01/17             76001.0             CALI
#
#       IDDEPARTAMENTONACIMIENTO    DEPARTAMENTONACIMIENTO  SISBEN  NIVELSISBEN  \
# 3532                      76.0           VALLE DEL CAUCA     0.0          NaN
# 9978                      76.0           VALLE DEL CAUCA     1.0          1.0
# 9052                      76.0           VALLE DEL CAUCA     0.0          NaN
# 8686                      11.0  BOGOTÁ, DISTRITO CAPITAL     0.0          NaN
# 2996                      76.0           VALLE DEL CAUCA     0.0          NaN
#
#       CANTIDAD  PERIODO  EDAD2                     EDAD      FACULTAD  \
# 3532         1  2021-II     22  Edad entre 18 y 25 años  Fac. Deporte
# 9978         1   2024-I     24  Edad entre 18 y 25 años    Fac. Admon
# 9052         1   2024-I     21  Edad entre 18 y 25 años    Fac. Salud
# 8686         1   2024-I     21  Edad entre 18 y 25 años    Fac. Salud
# 2996         1   2017-I     22  Edad entre 18 y 25 años  Fac. Deporte
#
#      NIVEL_FORMACION  target  COD_CIUDADRESIDENCIA Nombre_CIUDADRESIDENCIA  \
# 3532  Universitrario       1               76001.0                    CALI
# 9978  Universitrario       1               76001.0                    CALI
# 9052  Universitrario       1               76001.0                    CALI
# 8686  Universitrario       1               76563.0                 PRADERA
# 2996  Universitrario       0               76001.0                    CALI
#
#       COD_CIUDADNACIMIENTO Nombre_CIUDADNACIMIENTO
# 3532               76001.0                    CALI
# 9978               76001.0                    CALI
# 9052               76001.0                    CALI
# 8686               11001.0            BOGOTA. D.C.
# 2996               76001.0                    CALI

# %%
numeric_vars = ["ESTRATO", "SEMESTRE", "PROMEDIOSEMESTRE", "EDAD2",'CODIGOPROGRAMA',"GENERO","COD_CIUDADRESIDENCIA",'COD_CIUDADNACIMIENTO']
#category_vars = ["PROGRAMA", "GENERO", "CIUDADRESIDENCIA","CIUDADNACIMIENTO"]
category_vars =[]
target_var="target"
features=numeric_vars + category_vars
features
# Out:
# ['ESTRATO',
#  'SEMESTRE',
#  'PROMEDIOSEMESTRE',
#  'EDAD2',
#  'CODIGOPROGRAMA',
#  'GENERO',
#  'COD_CIUDADRESIDENCIA',
#  'COD_CIUDADNACIMIENTO']

# %% [markdown]
# Conversion de las variables categoricas a numericas utilizando codificacion, para asegurar que todas las variables de entrada al modelo sean numericas.

# %%
def get_df(df, target_var="target", numeric_vars=[], category_vars=[]):
  df = df.copy()
  label_encoder = LabelEncoder()
  for col in category_vars:
      df[col] = label_encoder.fit_transform(df[col].astype(str))
  df=df[ numeric_vars + category_vars+ [target_var]]
  return df

# %%
df=relacion
df=get_df(df, target_var, numeric_vars, category_vars)
df.sample(3)
# Out:
#        ESTRATO  SEMESTRE  PROMEDIOSEMESTRE  EDAD2  CODIGOPROGRAMA  GENERO  \
# 10206      3.0         2               4.0     24           90555       0
# 3450       2.0         8               4.1     22           53212       1
# 10232      3.0         2               4.3     56           90555       0
#
#        COD_CIUDADRESIDENCIA  COD_CIUDADNACIMIENTO  target
# 10206               76001.0               76001.0       1
# 3450                19142.0               19001.0       1
# 10232               76001.0               76001.0       1

# %% [markdown]
# * ***Identificacion valores nulos en las variables de entrada:***

# %%
df[[target_var]+features].isnull().sum() / df.shape[0]
# Out:
# target                  0.000000
# ESTRATO                 0.000578
# SEMESTRE                0.000000
# PROMEDIOSEMESTRE        0.000000
# EDAD2                   0.000000
# CODIGOPROGRAMA          0.000000
# GENERO                  0.000000
# COD_CIUDADRESIDENCIA    0.035171
# COD_CIUDADNACIMIENTO    0.006456
# dtype: float64

# %% [markdown]
# Se observa que pocas columnas del dataset tiene valores nulos, sin embargo representan un porcentaje minimo, por lo anterior decidimos conservar todas las variables de entrada.

# %%
duplicated_rows = df.loc[df.duplicated(subset=features, keep=False)].shape[0]
duplicated_rows
# Out:
# 1462

# %%
print(f"Duplicates: {(duplicated_rows/total_rows)*100:.4f}%")
# Out:
# Duplicates: 2.7577%

# %%
duplicated_rows = df.loc[df.duplicated(subset=features+["target"], keep=False)].shape[0]
duplicated_rows
# Out:
# 1385

# %%
print(f"Duplicates: {(duplicated_rows/total_rows)*100:.4f}%")
# Out:
# Duplicates: 2.6124%

# %% [markdown]
# Existe un ~2.75% de registros con variables de entrada duplicadas, incluso con variable objetivo diferente. Al incluir la variable objetivo dentro del análisis de duplicados, se obtiene el ~2.61% registros duplicados adicionales. Para un porcentaje total de 5,36%, se decide eliminar los datos duplicados con el fin de no afectar en la funcion de estimacion.

# %%
df.drop_duplicates(subset=features, inplace=True)
df.drop_duplicates(subset=features+["target"], inplace=True)

# %%
df.shape
# Out:
# (9453, 9)

# %%
df.to_csv('../../data/stage/clean.csv', index=False)
